# %% [markdown]
# # Study Case 5: Akses Presiden dari Wikipedia

# %%
import pandas as pd

df = pd.read_csv('../data/wikipedia_data/presidents.csv')
df.head()
# Out:
#                     name             birth                          tenure  \
# 0                Sukarno       6 June 1901  18 August 1945 - 12 March 1967
# 1                Suharto       8 June 1921     12 March 1967 - 21 May 1998
# 2          B. J. Habibie      25 June 1936   21 May 1998 - 20 October 1999
# 3      Abdurrahman Wahid  7 September 1940  20 October 1999 - 23 July 2001
# 4  Megawati Sukarnoputri   23 January 1947  23 July 2001 - 20 October 2004
#
#                                               spouse  \
# 0  ['Siti Oetari (Cerai)', 'Inggit Garnasih (Cera...
# 1                                  ['Siti Hartinah']
# 2                             ['Hasri Ainun Besari']
# 3                                  ['Sinta Nuriyah']
# 4  ['Surindro Supjarso', 'Hassan Gamal Ahmad Hass...
#
#                                                child  \
# 0  14, including Rukmini, Megawati, Rachmawati, S...
# 1      6, including Tutut, Titiek, and Tommy Suharto
# ...

# %%
df['spouse'] = df['spouse'].str.replace(r"[\[\]']", '', regex=True).str.replace(',', ', ', regex=False)
df['parent'] = df['parent'].str.replace(r"[\[\]']", '', regex=True).str.replace(',', ', ', regex=False)

df.head()
# Out:
#                     name             birth                          tenure  \
# 0                Sukarno       6 June 1901  18 August 1945 - 12 March 1967
# 1                Suharto       8 June 1921     12 March 1967 - 21 May 1998
# 2          B. J. Habibie      25 June 1936   21 May 1998 - 20 October 1999
# 3      Abdurrahman Wahid  7 September 1940  20 October 1999 - 23 July 2001
# 4  Megawati Sukarnoputri   23 January 1947  23 July 2001 - 20 October 2004
#
#                                               spouse  \
# 0  Siti Oetari (Cerai),  Inggit Garnasih (Cerai),...
# 1                                      Siti Hartinah
# 2                                 Hasri Ainun Besari
# 3                                      Sinta Nuriyah
# 4  Surindro Supjarso,  Hassan Gamal Ahmad Hassan,...
#
#                                                child  \
# 0  14, including Rukmini, Megawati, Rachmawati, S...
# 1      6, including Tutut, Titiek, and Tommy Suharto
# ...
