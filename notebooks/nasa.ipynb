# %%
import pandas as pd

df = pd.read_csv('../data/postgresql/response.csv')
df.head()
# Out:
#       id    country     level language catalog_type  \
# 0  59748  Australia  National  English        ckan3
# 1  54874  Australia  National  English        ckan3
# 2  55425  Australia  National  English        ckan3
# 3  56990  Australia  National  English        ckan3
# 4  59056  Australia  National  English        ckan3
#
#                                        english_title  \
# 0                    Polar Environmental Data Layers
# 1        MODIS derived Euphotic Depth (Zeu) datasets
# 2  AIMS Remote Sensing Data (Great Barrier Reef S...
# 3  MODIS derived Total Suspended Materials (TSM) ...
# 4  AIMS Remote Sensing Data (Great Barrier Reef S...
#
#                english_keywords english_category  \
# 0  ,,,,,,,,,,,,,,,,,,,,,,,,,,,,              NaN
# 1                           ,,,              NaN
# 2                          ,,,,              NaN
# 3                           ,,,              NaN
# 4                          ,,,,              NaN
#
# ...
